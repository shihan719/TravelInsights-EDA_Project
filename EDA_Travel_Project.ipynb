# %% [markdown]
# <span style="color:pink">
#
# # TRAVEL INSIGHTS</span>

# %% [markdown]
# ---

# %% [markdown]
# <span style="font-family:Calibri">In my ***<span style="color:yellow">Exploratory Data Analysis (EDA) project</span>*** focused on a ***<span style="color:yellow">Travel Insights</span>*** dataset, I meticulously curated and cleaned the dataset comprising columns such as *Trip ID, Destination, Start Date, End Date, Duration (days), Traveler Name, Traveler Age, Traveler Gender, Traveler Nationality, Accommodation Type, Accommodation Cost, Transportation Type, and Transportation Cost*. Employing a systematic approach, I delved into data cleaning procedures to ensure data integrity. Subsequently, I conducted a comprehensive analysis, applying various statistical and computational operations to extract meaningful insights. The project involved the synthesis of graphical representations, leveraging diverse plotting techniques to visually convey patterns and trends within the dataset. This multifaceted EDA initiative not only showcases my adept data handling skills but also underscores my proficiency in interpreting and communicating nuanced findings through impactful visualizations.</span>

# %% [markdown]
# <span style="color:Orange"> Importing the required libraries for EDA </span>
#
# <span style="font-family:Calibri">The project begins by importing essential libraries, including Pandas for data manipulation, ***NumPy*** for *numerical* operations, Seaborn and Matplotlib for data visualization, and setting Seaborn color codes for enhanced visualizations.</span>

# %%
import pandas as pd
import numpy as np
import seaborn as sns                       #visualisation
import matplotlib.pyplot as plt             #visualisation
# %matplotlib inline     
sns.set(color_codes=True)

# %% [markdown]
# <span style="color:Orange"> Loading the data into the data frame. </span>
#
# <span style="font-family:Calibri">Loading dataframes involves importing datasets from various file formats such as ***CSV***, ***Excel***, or ***databases*** into programming environments like Python using libraries such as *pandas*.</span>

# %%
# Load the Excel file into a DataFrame

file1 = 'Travel details dataset.xlsx'
Travel = pd.read_excel(file1, sheet_name='Travel details dataset', header=0)

#View the data
Travel
# Out:
#      Trip ID             Destination           Start date  \
# 0          1              London, UK  2023-01-05 00:00:00
# 1          2        Phuket, Thailand            6/15/2023
# 2          3         Bali, Indonesia  2023-01-07 00:00:00
# 3          4           New York, USA            8/15/2023
# 4          5            Tokyo, Japan  2023-10-09 00:00:00
# ..       ...                     ...                  ...
# 132      135  Rio de Janeiro, Brazil  2023-01-08 00:00:00
# 133      136       Vancouver, Canada            8/15/2023
# 134      137       Bangkok, Thailand  2023-01-09 00:00:00
# 135      138        Barcelona, Spain            9/15/2023
# 136      139   Auckland, New Zealand  2023-01-10 00:00:00
#
#                 End date  Duration (days)    Traveler name  Traveler age  \
# 0    2023-08-05 00:00:00                7       John Smith            35
# 1              6/20/2023                5         Jane Doe            28
# ...

# %% [markdown]
# <span style="font-family:Calibri">Inserting a new column <span style="color:Orange">'Total cost'</span>, the sum of <span style="color:Orange">'Accommodation cost'</span> and <span style="color:Orange">'Transportation cost'</span> columns.</span>

# %%
Travel['Total cost'] = Travel['Accommodation cost'] + Travel['Transportation cost']
Travel
# Out:
#      Trip ID             Destination           Start date  \
# 0          1              London, UK  2023-01-05 00:00:00
# 1          2        Phuket, Thailand            6/15/2023
# 2          3         Bali, Indonesia  2023-01-07 00:00:00
# 3          4           New York, USA            8/15/2023
# 4          5            Tokyo, Japan  2023-10-09 00:00:00
# ..       ...                     ...                  ...
# 132      135  Rio de Janeiro, Brazil  2023-01-08 00:00:00
# 133      136       Vancouver, Canada            8/15/2023
# 134      137       Bangkok, Thailand  2023-01-09 00:00:00
# 135      138        Barcelona, Spain            9/15/2023
# 136      139   Auckland, New Zealand  2023-01-10 00:00:00
#
#                 End date  Duration (days)    Traveler name  Traveler age  \
# 0    2023-08-05 00:00:00                7       John Smith            35
# 1              6/20/2023                5         Jane Doe            28
# ...

# %% [markdown]
# <span style="color:Orange">Tail<span>
#
# <span style="font-family:Calibri">The <span style="color:Orange">Tail</span> operations involve examining the last few rows of a dataset, providing insights into the concluding data points.</span>

# %%
# To display the botton 5 rows
Travel.tail(5)
# Out:
#      Trip ID             Destination           Start date  \
# 132      135  Rio de Janeiro, Brazil  2023-01-08 00:00:00
# 133      136       Vancouver, Canada            8/15/2023
# 134      137       Bangkok, Thailand  2023-01-09 00:00:00
# 135      138        Barcelona, Spain            9/15/2023
# 136      139   Auckland, New Zealand  2023-01-10 00:00:00
#
#                 End date  Duration (days)    Traveler name  Traveler age  \
# 132  2023-10-08 00:00:00                9       Jose Perez            37
# 133            8/21/2023                6      Emma Wilson            29
# 134  2023-08-09 00:00:00                7        Ryan Chen            34
# 135            9/22/2023                7  Sofia Rodriguez            25
# 136  2023-08-10 00:00:00                7    William Brown            39
#
#     Traveler gender Traveler nationality Accommodation type  \
# 132            Male            Brazilian             Hostel
# ...

# %% [markdown]
# <span style="font-family:Calibri">Applying cell formatting to <span style="color:Orange">'Start date'</span> and <span style="color:Orange">'End date'</span> columns for improved visual clarity and consistency.</span>

# %%
Travel['Start date'] = pd.to_datetime(Travel['Start date'])
Travel['End date'] = pd.to_datetime(Travel['End date'])
Travel
# Out:
#      Trip ID             Destination Start date   End date  Duration (days)  \
# 0          1              London, UK 2023-01-05 2023-08-05                7
# 1          2        Phuket, Thailand 2023-06-15 2023-06-20                5
# 2          3         Bali, Indonesia 2023-01-07 2023-08-07                7
# 3          4           New York, USA 2023-08-15 2023-08-29               14
# 4          5            Tokyo, Japan 2023-10-09 2023-09-17                7
# ..       ...                     ...        ...        ...              ...
# 132      135  Rio de Janeiro, Brazil 2023-01-08 2023-10-08                9
# 133      136       Vancouver, Canada 2023-08-15 2023-08-21                6
# 134      137       Bangkok, Thailand 2023-01-09 2023-08-09                7
# 135      138        Barcelona, Spain 2023-09-15 2023-09-22                7
# 136      139   Auckland, New Zealand 2023-01-10 2023-08-10                7
#
# ...

# %% [markdown]
# <span style="color:Orange">Checking the types of data</span>
#
# <span style="font-family:Calibri">In the initial stage, I verified the data types of each column in the dataset to ensure consistency and accuracy.</span>

# %%
Travel.dtypes
# Out:
# Trip ID                          int64
# Destination                     object
# Start date              datetime64[ns]
# End date                datetime64[ns]
# Duration (days)                  int64
# Traveler name                   object
# Traveler age                     int64
# Traveler gender                 object
# Traveler nationality            object
# Accommodation type              object
# Accommodation cost               int64
# Transportation type             object
# Transportation cost            float64
# Total cost                     float64
# dtype: object

# %% [markdown]
# <span style="font-family:Calibri">Converted the data type of the <span style="color:Orange">'Accommodation cost'</span> column to <span style="color:Orange">'int64'</span>.</span>

# %%
# Convert int64 to float64
Travel['Accommodation cost'] = Travel['Accommodation cost'].astype('float64')

# %% [markdown]
# <span style="color:Orange">Info</span>
#
# <span style="font-family:Calibri">The <span style="color:Orange">"Info"</span> operation is used to obtain a concise summary of the essential information about a dataset, offering a quick overview of its <span style="color:Orange">structure</span>,<span style="color:Orange"> data types</span> and <span style="color:Orange">missing values</span>.</span>

# %%
Travel_info = Travel.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 137 entries, 0 to 136
# Data columns (total 14 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Trip ID               137 non-null    int64
#  1   Destination           137 non-null    object
#  2   Start date            137 non-null    datetime64[ns]
#  3   End date              137 non-null    datetime64[ns]
#  4   Duration (days)       137 non-null    int64
#  5   Traveler name         137 non-null    object
#  6   Traveler age          137 non-null    int64
#  7   Traveler gender       137 non-null    object
#  8   Traveler nationality  137 non-null    object
#  9   Accommodation type    137 non-null    object
#  10  Accommodation cost    137 non-null    float64
#  11  Transportation type   136 non-null    object
#  12  Transportation cost   136 non-null    float64
#  13  Total cost            136 non-null    float64
# ...

# %% [markdown]
# <span style="color:Orange">Describe</span>
#
# <span style="font-family:Calibri">The <span style="color:Orange">"describe()"</span> operation provides a concise statistical summary of the dataset's numerical attributes, including measures like <span style="color:orange">mean</span>, <span style="color:orange">median</span>, <span style="color:orange">standard deviation</span>, <span style="color:orange">minimum</span> and <span style="color:orange">maximum values</span>.</span>

# %%
Travel_describe = Travel.describe()
Travel_describe
# Out:
#           Trip ID  Duration (days)  Traveler age  Accommodation cost  \
# count  137.000000       137.000000    137.000000          137.000000
# mean    69.562044         7.605839     33.175182         1245.109489
# std     40.256140         1.601276      7.145441         1337.349836
# min      1.000000         5.000000     20.000000          100.000000
# 25%     35.000000         7.000000     28.000000          600.000000
# 50%     69.000000         7.000000     31.000000          900.000000
# 75%    104.000000         8.000000     38.000000         1200.000000
# max    139.000000        14.000000     60.000000         8000.000000
#
#        Transportation cost    Total cost
# count           136.000000    136.000000
# mean            645.183824   1898.713235
# std             584.476153   1834.553533
# min              20.000000    200.000000
# 25%             200.000000   1000.000000
# 50%             550.000000   1400.000000
# 75%             800.000000   1900.000000
# ...

# %% [markdown]
# <span style="color:Orange">Value Count </span>
#
# <span style="font-family:Calibri">The <span style="color:Orange"> "value_counts()" </span>function is then used to count how many times each unique traveler name appears in that column. It gives you a tally of the number of occurrences for each traveler's name in the dataset.</span>

# %%
#Get the unique category counts

Travel_unique_categ_count= Travel['Traveler name'].value_counts()
Travel_unique_categ_count
# Out:
# John Smith       6
# David Lee        6
# David Kim        4
# Sarah Lee        4
# Emily Davis      3
#                 ..
# Peter Brown      1
# Maria Silva      1
# Sarah Wong       1
# Adam Lee         1
# William Brown    1
# Name: Traveler name, Length: 109, dtype: int64

# %% [markdown]
# <span style="color:Orange">Split()</span>
#
# <span style="font-family:Calibri">Utilized the space <span style="color:Orange">(' ')</span> as a delimiter to split <span style="color:Orange">'Traveler name' </span>into <span style="color:Orange">'First name' </span> and <span style="color:Orange">'Last name'</span> columns in the dataset, effectively extracting distinct elements and enhancing data granularity.<span style="font-family:Calibri">

# %%
Travel[['First name', 'Last name']] = Travel['Traveler name'].str.split(pat=' ', n=1, expand=True)
Travel
# Out:
#      Trip ID             Destination Start date   End date  Duration (days)  \
# 0          1              London, UK 2023-01-05 2023-08-05                7
# 1          2        Phuket, Thailand 2023-06-15 2023-06-20                5
# 2          3         Bali, Indonesia 2023-01-07 2023-08-07                7
# 3          4           New York, USA 2023-08-15 2023-08-29               14
# 4          5            Tokyo, Japan 2023-10-09 2023-09-17                7
# ..       ...                     ...        ...        ...              ...
# 132      135  Rio de Janeiro, Brazil 2023-01-08 2023-10-08                9
# 133      136       Vancouver, Canada 2023-08-15 2023-08-21                6
# 134      137       Bangkok, Thailand 2023-01-09 2023-08-09                7
# 135      138        Barcelona, Spain 2023-09-15 2023-09-22                7
# 136      139   Auckland, New Zealand 2023-01-10 2023-08-10                7
#
# ...

# %% [markdown]
# <span style="color:Orange">drop()<span>
#
# <span style="font-family:Calibri">Dropping operation to remove irrelevant or redundant columns or rows from the dataset, streamlining the data for more focused analysis.</span>

# %%
Travel = Travel.drop(['First name', 'Last name'], axis=1)
Travel.head(5)
# Out:
#    Trip ID       Destination Start date   End date  Duration (days)  \
# 0        1        London, UK 2023-01-05 2023-08-05                7
# 1        2  Phuket, Thailand 2023-06-15 2023-06-20                5
# 2        3   Bali, Indonesia 2023-01-07 2023-08-07                7
# 3        4     New York, USA 2023-08-15 2023-08-29               14
# 4        5      Tokyo, Japan 2023-10-09 2023-09-17                7
#
#    Traveler name  Traveler age Traveler gender Traveler nationality  \
# 0     John Smith            35            Male             American
# 1       Jane Doe            28          Female             Canadian
# 2      David Lee            45            Male               Korean
# 3  Sarah Johnson            29          Female              British
# 4     Kim Nguyen            26          Female           Vietnamese
#
#   Accommodation type  Accommodation cost Transportation type  \
# 0              Hotel              1200.0              Flight
# ...

# %% [markdown]
# <span style="color:Orange">rename()</span>
#
# <span style="font-family:Calibri">The <span style="color:Orange">"rename"</span> operation is employed to update or modify the names of columns in a dataset, enhancing clarity and improving data interpretability.</span>

# %%
Travel = Travel.rename(columns={"Traveler name": "Name","Traveler age": "Age", "Traveler gender": "Gender", "Traveler nationality": "Nationality" })
Travel.head(5)
# Out:
#    Trip ID       Destination Start date   End date  Duration (days)  \
# 0        1        London, UK 2023-01-05 2023-08-05                7
# 1        2  Phuket, Thailand 2023-06-15 2023-06-20                5
# 2        3   Bali, Indonesia 2023-01-07 2023-08-07                7
# 3        4     New York, USA 2023-08-15 2023-08-29               14
# 4        5      Tokyo, Japan 2023-10-09 2023-09-17                7
#
#             Name  Age  Gender Nationality Accommodation type  \
# 0     John Smith   35    Male    American              Hotel
# 1       Jane Doe   28  Female    Canadian             Resort
# 2      David Lee   45    Male      Korean              Villa
# 3  Sarah Johnson   29  Female     British              Hotel
# 4     Kim Nguyen   26  Female  Vietnamese             Airbnb
#
#    Accommodation cost Transportation type  Transportation cost  Total cost
# 0              1200.0              Flight                600.0      1800.0
# ...

# %% [markdown]
# <span style="color:Orange">shape</span>
#
# <span style="font-family:Calibri">The <span style="color:Orange">'shape'</span> is used to determine the dimensions (rows and columns) of a dataset, providing a quick overview of its structure.</span>

# %%
Travel.shape
# Out:
# (137, 14)

# %% [markdown]
# <span style="color:Orange">count()</span>
#
# <span style="font-family:Calibri">The <span style="color:Orange">count</span> operation is utilized to determine the number of occurrences of a specific value or entries within a dataset column.</span>

# %%
Travel.count()      # Used to count the number of rows
# Out:
# Trip ID                137
# Destination            137
# Start date             137
# End date               137
# Duration (days)        137
# Name                   137
# Age                    137
# Gender                 137
# Nationality            137
# Accommodation type     137
# Accommodation cost     137
# Transportation type    136
# Transportation cost    136
# Total cost             136
# dtype: int64

# %% [markdown]
# <span style="color:Orange">Duplicate rows</span>
#
# <span style="font-family:Calibri">Displays the duplicate rows in the <span style="color:pink">" Travel "</span> dataset, and then prints the count of these duplicates.</span>

# %%
duplicate_rows_Travel = Travel[Travel.duplicated()]
print("Number of duplicate rows: ", duplicate_rows_Travel.shape)
# Out:
# Number of duplicate rows:  (0, 14)

# %% [markdown]
# <span style="color:Orange">drop duplicates</span>
#
# <span style="font-family:Calibri">The <span style="color:Orange">" Drop Duplicates "</span> is to eliminate identical rows in a dataset, ensuring that each entry is unique and preventing redundant information in the analysis.</span>

# %%
Travel = Travel.drop_duplicates()
Travel.head(5)
# Out:
#    Trip ID       Destination Start date   End date  Duration (days)  \
# 0        1        London, UK 2023-01-05 2023-08-05                7
# 1        2  Phuket, Thailand 2023-06-15 2023-06-20                5
# 2        3   Bali, Indonesia 2023-01-07 2023-08-07                7
# 3        4     New York, USA 2023-08-15 2023-08-29               14
# 4        5      Tokyo, Japan 2023-10-09 2023-09-17                7
#
#             Name  Age  Gender Nationality Accommodation type  \
# 0     John Smith   35    Male    American              Hotel
# 1       Jane Doe   28  Female    Canadian             Resort
# 2      David Lee   45    Male      Korean              Villa
# 3  Sarah Johnson   29  Female     British              Hotel
# 4     Kim Nguyen   26  Female  Vietnamese             Airbnb
#
#    Accommodation cost Transportation type  Transportation cost  Total cost
# 0              1200.0              Flight                600.0      1800.0
# ...

# %% [markdown]
# <span style="color:Orange">Count</span>
#
# <span style="font-family:Calibri">Number of travel entries in the dataset using <span style="color:Orange">" count() "<span>.</span>

# %%
Travel.count()
# Out:
# Trip ID                137
# Destination            137
# Start date             137
# End date               137
# Duration (days)        137
# Name                   137
# Age                    137
# Gender                 137
# Nationality            137
# Accommodation type     137
# Accommodation cost     137
# Transportation type    136
# Transportation cost    136
# Total cost             136
# dtype: int64

# %% [markdown]
# <span style="color:Orange">Missing or null values</sapn>
#
# <span style="font-family:Calibri">Sum of missing values in the dataset.</span>

# %%
print(Travel.isnull().sum())
# Out:
# Trip ID                0
# Destination            0
# Start date             0
# End date               0
# Duration (days)        0
# Name                   0
# Age                    0
# Gender                 0
# Nationality            0
# Accommodation type     0
# Accommodation cost     0
# Transportation type    1
# Transportation cost    1
# Total cost             1
# dtype: int64

# %% [markdown]
# <span style="color:Orange">Dropping 'na'</span>
#
# <span style="font-family:Calibri">Removes missing values from the dataset.</span>

# %%
Travel = Travel.dropna()    # Dropping the missing values.
Travel.count()
# Out:
# Trip ID                136
# Destination            136
# Start date             136
# End date               136
# Duration (days)        136
# Name                   136
# Age                    136
# Gender                 136
# Nationality            136
# Accommodation type     136
# Accommodation cost     136
# Transportation type    136
# Transportation cost    136
# Total cost             136
# dtype: int64

# %% [markdown]
# <span style="font-family:Calibri">After dropping the values, print the *<span style="color:Orange">count of null values</span>* in the Travel dataframe.</span>

# %%
print(Travel.isnull().sum())   # After dropping the values
# Out:
# Trip ID                0
# Destination            0
# Start date             0
# End date               0
# Duration (days)        0
# Name                   0
# Age                    0
# Gender                 0
# Nationality            0
# Accommodation type     0
# Accommodation cost     0
# Transportation type    0
# Transportation cost    0
# Total cost             0
# dtype: int64

# %% [markdown]
# <span style="color:Orange">Detecting Outliers</span>

# %%
sns.boxplot(x=Travel['Duration (days)'])
# Out:
# <Axes: xlabel='Duration (days)'>

# %%
sns.boxplot(x=Travel['Total cost'])
# Out:
# <Axes: xlabel='Total cost'>

# %%
sns.boxplot(x=Travel['Age'])
# Out:
# <Axes: xlabel='Age'>

# %% [markdown]
# <span style="font-family:Calibri">The code utilizes Seaborn's ***<span style="color:Orange">boxplot</span>*** function to visually detect outliers in the 'Duration (days)' column of the Travel dataset.</span>

# %% [markdown]
# <span style="color:Orange">IQR</span> (Interquartile Range)

# %%
Q1 = Travel.quantile(0.25, numeric_only=True)
Q3 = Travel.quantile(0.75, numeric_only=True)
IQR = Q3 - Q1
IQR
# Out:
# Trip ID                 69.50
# Duration (days)          1.00
# Age                      9.25
# Accommodation cost     600.00
# Transportation cost    600.00
# Total cost             900.00
# dtype: float64

# %% [markdown]
# <span style="font-family:Calibri">The code calculates the <span style="color:Orange">interquartile range (IQR)</span> of the 'Travel' data using the ***first quartile (Q1)*** and ***third quartile (Q3)*** values.</span>

# %% [markdown]
# <span style="color:Orange">Bar plot</span>

# %%
Travel.Destination.value_counts().nlargest(40).plot(kind='bar', figsize=(10,5))
plt.title("Number of travelers visited various destinations")
plt.ylabel('Number of Traveler')
plt.xlabel('Destination');

# %% [markdown]
# <span style="font-family:Calibri">The <span style="color:Orange">Bar Plot</span> visually represents the number of travelers who visited various destinations, with each bar corresponding to a specific destination and its height indicating the corresponding traveler count.</span>

# %% [markdown]
# <span style="color:Orange">Heat Map</span>

# %%
plt.figure(figsize=(10, 5))
c = Travel.corr(numeric_only=True)  # Set numeric_only to True
sns.heatmap(c, cmap="BrBG", annot=True)
plt.show()  # Added plt.show() to display the plot
c
# Out:
#                       Trip ID  Duration (days)       Age  Accommodation cost  \
# Trip ID              1.000000        -0.039328  0.065517            0.348656
# Duration (days)     -0.039328         1.000000 -0.118039           -0.129948
# Age                  0.065517        -0.118039  1.000000            0.039396
# Accommodation cost   0.348656        -0.129948  0.039396            1.000000
# Transportation cost  0.448495        -0.001185  0.054533            0.787319
# Total cost           0.397296        -0.095198  0.046121            0.980518
#
#                      Transportation cost  Total cost
# Trip ID                         0.448495    0.397296
# Duration (days)                -0.001185   -0.095198
# Age                             0.054533    0.046121
# Accommodation cost              0.787319    0.980518
# Transportation cost             1.000000    0.893087
# Total cost                      0.893087    1.000000

# %% [markdown]
# <span style="font-family:Calibri">**<span style="color:Orange">Heatmap</span>** using ***Seaborn*** to visualize the correlation matrix (c) of numeric data in the 'Travel' dataset, with annotations and a Brown-Blue-Green color map.</span>

# %% [markdown]
# <span style="color:Orange">Scatterplot</span>

# %%
fig, ax = plt.subplots(figsize=(9,11))
ax.scatter(Travel['Total cost'], Travel['Destination'])
ax.set_xlabel('Total cost')
ax.set_ylabel('Destination')
plt.show()

# %% [markdown]
# <span style="font-family:Calibri"><span style="color:Orange">Scatterplot</span> using ***Matplotlib***, visualizing the relationship between total travel cost and destination from the 'Travel' dataset.</span>

# %% [markdown]
# <span style="color:Orange">Histogram</span>

# %%
import matplotlib.pyplot as plt

# Assuming Travel is a DataFrame and 'Total cost' is a column in it
less_than_200 = Travel[Travel['Total cost'] < 1800]

# Plot histogram
plt.hist(less_than_200['Total cost'], bins=20, color='blue', edgecolor='black')

# Add labels and title
plt.xlabel('Total cost')
plt.ylabel('')
plt.title('Histogram of Total Cost (Values less than 200)')

# Show the plot
plt.show()

# %% [markdown]
# Using ***Matplotlib*** for the 'Total cost' column in the Travel DataFrame, considering values less than 1800, with 20 bins and blue color, providing insights into the distribution of costs.</span>

# %% [markdown]
# <span style="color:Orange">Pair Plot</span>

# %%
import seaborn as sns

# Assuming Travel is a DataFrame and you want to include 'Total cost', 'Transportation cost', and 'Accommodation cost'
selected_columns = ['Total cost', 'Transportation cost', 'Accommodation cost']

# Filter the DataFrame to include only the selected columns
selected_data = Travel[selected_columns]

# Create a pair plot
sns.pairplot(selected_data)

# Show the plot
plt.show()

# %% [markdown]
# <span style="font-family:Calibri">Using ***Seaborn*** to generate a <span style="color:Orange">pair plot</span> for selected cost-related columns ('Total cost', 'Transportation cost', 'Accommodation cost') from the Travel DataFrame.</span>

# %% [markdown]
# <span style="color:Orange">Count Plot</span>

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming Travel is a DataFrame and 'Accommodation type' is a categorical column
sns.countplot(x='Accommodation type', data=Travel)

# Rotate x-axis labels for better visibility (optional)
plt.xticks(rotation=45, ha='right')

# Add labels and title
plt.xlabel('Accommodation Type')
plt.ylabel('Count')
plt.title('Count Plot of Accommodation Types')

# Show the plot
plt.show()

# %% [markdown]
# <span style="font-family:Calibri">Using *Seaborn* to create a <span style="color:Orange">count plot</span> of 'Accommodation type' from the Travel DataFrame, with rotated x-axis labels for better visibility and added labels and title.</span>

# %% [markdown]
# <span style="color:Orange">Pie Chart</span>

# %%
import matplotlib.pyplot as plt

# Assuming Travel is a DataFrame and 'Accommodation type' is a categorical column
accommodation_counts = Travel['Accommodation type'].value_counts()

# Plot pie chart
plt.pie(accommodation_counts, labels=accommodation_counts.index, autopct='%1.1f%%', startangle=120)

# Add title
plt.title('Distribution of Accommodation Types')

# Show the plot
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle
plt.show()

# %% [markdown]
# <span style="font-family:Calibri">Using *Matplotlib* to create a <span style="color:Orange">pie chart</span> illustrating the distribution of accommodation types in the 'Travel' DataFrame.</span>

# %% [markdown]
# <span style="color:Orange">Dist Plot</span>

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming Travel is a DataFrame and 'Total cost' is a numerical column
sns.histplot(Travel['Total cost'], kde=False, bins=20, color='blue')

# Add labels and title
plt.xlabel('Total cost')
plt.ylabel('Frequency')
plt.title('Distribution of Total Cost')

# Show the plot
plt.show()

# %% [markdown]
# <span style="font-family:Calibri">Utilizes *Seaborn and Matplotlib* to create a histogram <span style="color:Orange">(distplot)</span> of the 'Total cost' column in the Travel DataFrame, with 20 bins and a blue color, presenting the distribution of total costs with labeled axes and a title.</span>

# %% [markdown]
# ---

# %% [markdown]
# <span style="font-family:Calibri"><span style="color:yellow">*Some findings..*</span></span>

# %% [markdown]
# ---

# %% [markdown]
# <span style="font-family:Calibri"><span style="color:pink">
# > How many travelers are visiting the same destination ?</span>

# %%
most_repeated_destination = Travel['Destination'].value_counts().idxmax()
print("Repeated destination:", most_repeated_destination)
print("No of Visited Same destination:", Travel['Destination'].value_counts().max())
# Out:
# Repeated destination: Paris
# No of Visited Same destination: 7

# %% [markdown]
# <span style="font-family:Calibri"><span style="color:pink">
# >Can you provide the list of accommodation types along with their respective counts in the dataset ?</span></span>

# %%
Travel_Hotel = Travel['Accommodation type'].value_counts().idxmax()
print("List the count of Accommodated:", Travel['Accommodation type'].value_counts())
# Out:
# List the count of Accommodated: Hotel              59
# Airbnb             30
# Hostel             24
# Resort             14
# Villa               4
# Vacation rental     3
# Riad                1
# Guesthouse          1
# Name: Accommodation type, dtype: int64

# %% [markdown]
# <span style="font-family:Calibri"><span style="color:pink">
# >How can you use pandas to filter the 'Travel' DataFrame to obtain rows where the 'Total cost' is less than 1800 and the 'Accommodation type' is specifically 'Hotel' ?</span></span>

# %%
import pandas as pd

Travel_filter = Travel[(Travel['Total cost'] < 1800) & (Travel['Accommodation type'] == 'Hotel')]
Travel_filter
# Out:
#      Trip ID             Destination Start date   End date  Duration (days)  \
# 8          9  Amsterdam, Netherlands 2024-02-14 2024-02-21                7
# 10        11          Cancun, Mexico 2024-01-04 2024-08-04                7
# 15        16     Edinburgh, Scotland 2024-05-09 2024-12-09                7
# 16        17                   Paris 2023-01-09 2023-10-09                9
# 18        19                  London 2023-07-22 2023-07-28                6
# 21        22                  Sydney 2023-05-12 2023-12-12                7
# 24        25                   Paris 2023-12-22 2023-12-28                6
# 26        27               Barcelona 2023-10-20 2023-10-28                8
# 27        28                   Japan 2022-10-05 2022-05-18                8
# 30        31               Australia 2022-08-20 2022-02-09               13
# 33        34                   Egypt 2022-08-11 2022-11-15                7
# ...

# %% [markdown]
# ----

# %% [markdown]
# <span style="color:yellow">***Exploratory Questions:***</span>

# %% [markdown]
# ---

# %% [markdown]
# <span style="color:orange">
#
# ***Destination Insights :***
#
# </span>
#
# <span style="font-family:Calibri"><span style="color:pink">
# >Which destinations are the most frequently visited ?</span>

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Convert the 'Destination' column to lowercase to handle variations in case
Travel['Destination'] = Travel['Destination'].str.lower()

# Count the frequency of each destination
destination_counts = Travel['Destination'].value_counts()

# Display the top 5 most frequently visited destinations
top_destinations = destination_counts.head(5)
print("Top 5 Most Frequently Visited Destinations:")
print(top_destinations)
# Out:
# Top 5 Most Frequently Visited Destinations:
# paris            7
# tokyo, japan     7
# paris, france    7
# bali             7
# tokyo            5
# Name: Destination, dtype: int64

# %% [markdown]
# <span style="font-family:Calibri"><span style="color:pink">
# >What is the average duration of trips for each destination ?</span>

# %%
import pandas as pd

# Assuming your travel data is stored in a DataFrame called 'travel_data'
# Convert 'Start date' and 'End date' columns to datetime format if they are not already
Travel['Start date'] = pd.to_datetime(Travel['Start date'])
Travel['End date'] = pd.to_datetime(Travel['End date'])

# Calculate duration for each trip
Travel['Duration'] = (Travel['End date'] - Travel['Start date']).dt.days

# Calculate average duration for each destination
average_duration_per_destination = Travel.groupby('Destination')['Duration'].mean().reset_index()
print(average_duration_per_destination)
# Out:
#                     Destination    Duration
# 0                     amsterdam    7.000000
# 1        amsterdam, netherlands    7.500000
# 2                athens, greece   10.000000
# 3         auckland, new zealand  212.000000
# 4                     australia -192.000000
# 5                          bali   12.571429
# 6               bali, indonesia   37.600000
# 7                       bangkok    7.750000
# 8                 bangkok, thai    7.000000
# 9             bangkok, thailand  212.333333
# 10                    barcelona    7.500000
# 11             barcelona, spain    0.000000
# 12              berlin, germany  274.000000
# 13                       brazil  128.000000
# 14                       canada    7.000000
# 15               cancun, mexico  110.000000
# 16                    cape town -152.500000
# 17                cape town, sa  273.000000
# 18      cape town, south africa  273.000000
# 19                        dubai  108.500000
# ...

# %% [markdown]
# <span style="color:orange">
#
# ***Traveler Demographics :***</span>
#
# <span style="font-family:Calibri"><span style="color:pink">
# >What is the distribution of traveler ages ?</span>

# %%
import matplotlib.pyplot as plt
import pandas as pd


Travel_age = pd.read_excel(file1, sheet_name='Travel details dataset', header=0)

ages = Travel_age['Traveler age']

# Define bins
bins = [20, 30, 40, 50, 60, 70, 80, 90, 100]

# Create histogram
plt.hist(ages, bins=bins, edgecolor='black', alpha=0.7)

# Add labels and title
plt.xlabel('Age Groups')
plt.ylabel('Number of Travelers')
plt.title('Distribution of Traveler Ages')

# Show the plot
plt.show()

# %% [markdown]
# <span style="font-family:Calibri"><span style="color:pink">
# >How does the gender distribution vary among travelers ?</span>

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming your dataframe is named 'travel_data'
gender_distribution = Travel['Traveler gender'].value_counts()
total_travelers = len(Travel)

# Calculate gender percentage
gender_percentage = (gender_distribution / total_travelers) * 100

# Visualize gender distribution
plt.figure(figsize=(8, 6))
plt.pie(gender_percentage, labels=gender_percentage.index, autopct='%1.1f%%', startangle=90, colors=['skyblue', 'lightcoral'])
plt.title('Gender Distribution Among Travelers')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\shihan\anaconda3\lib\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File c:\Users\shihan\anaconda3\lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File c:\Users\shihan\anaconda3\lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Traveler gender'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %% [markdown]
# <span style="font-family:Calibri"><span style="color:pink">
# >What is the most common accommodation type chosen by travelers ?</span>

# %%
import pandas as pd

# Count the occurrences of each accommodation type
accommodation_counts = Travel['Accommodation type'].value_counts()

# Find the most common accommodation type
most_common_accommodation = accommodation_counts.idxmax()

print("The most common accommodation type chosen by travelers is:", most_common_accommodation)
# Out:
# The most common accommodation type chosen by travelers is: Hotel

# %% [markdown]
# <span style="font-family:Calibri"><span style="color:pink">
# >Which transportation mode is preferred by most travelers ?</span>

# %%
import pandas as pd

# Assuming your data is stored in a DataFrame named 'travel_data'
# Replace 'transportation_type_column_name' with the actual column name in your data
transportation_distribution = (Travel['Transportation type'].value_counts(normalize=True) * 100).astype(int)

# Print the distribution
print(transportation_distribution)

# Identify the preferred transportation mode
preferred_transportation = transportation_distribution.idxmax()
print(f"The preferred transportation mode is: {preferred_transportation}")
# Out:
# Plane         41
# Train         27
# Flight         9
# Car rental     9
# Bus            4
# Airplane       3
# Car            2
# Subway         0
# Ferry          0
# Name: Transportation type, dtype: int32
# The preferred transportation mode is: Plane

# %% [markdown]
# <span style="font-family:Calibri"><span style="color:pink">
# >How does trip duration vary throughout the year ?</span>

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Assuming your DataFrame is named 'travel_data'
# Convert 'Start date' and 'End date' columns to datetime
Travel['Start date'] = pd.to_datetime(Travel['Start date'])
Travel['End date'] = pd.to_datetime(Travel['End date'])

# Calculate trip duration in days
Travel['Trip duration'] = (Travel['End date'] - Travel['Start date']).dt.days

# Group by month and calculate average trip duration
monthly_avg_duration = Travel.groupby(Travel['Start date'].dt.month)['Trip duration'].mean()

# Plotting
plt.figure(figsize=(10, 6))
plt.plot(monthly_avg_duration.index, monthly_avg_duration, marker='o', linestyle='-', color='b')
plt.title('Average Trip Duration Throughout the Year')
plt.xlabel('Month')
plt.ylabel('Average Trip Duration (days)')
plt.xticks(range(1, 13), ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'])
plt.grid(True)
plt.show()

# %% [markdown]
# <span style="color:Orange">
#
# ***Operational Questions :***
#
# </span>
#
# <span style="font-family:Calibri"><span style="color:pink">
# >What is the average total cost of the trip ?</span></span>

# %%
import pandas as pd

Travel_avg = pd.read_excel(file1, sheet_name='Travel details dataset', header=0)

# Calculate total cost for each trip
Travel_avg['Total Cost'] = Travel_avg['Accommodation cost'] + Travel_avg['Transportation cost']

# Calculate the average total cost
average_total_cost = Travel_avg['Total Cost'].mean()

print(f"The average total cost of a trip is: ${average_total_cost:.2f}")
# Out:
# The average total cost of a trip is: $1898.71

# %% [markdown]
# <span style="font-family:Calibri"><span style="color:pink">
# >Is there a correlation between the booking lead time and accommodation cost ?</span>

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming your data is stored in a DataFrame named 'travel_data'
# Ensure 'Start date' is in datetime format
Travel['Start date'] = pd.to_datetime(Travel['Start date'])

# Calculate booking lead time
Travel['Lead time'] = (Travel['Start date'] - pd.to_datetime('today')).dt.days

# Scatter plot
plt.scatter(Travel['Lead time'], Travel['Accommodation cost'])
plt.xlabel('Booking Lead Time (days)')
plt.ylabel('Accommodation Cost')
plt.title('Correlation between Booking Lead Time and Accommodation Cost')
plt.show()

# Calculate correlation coefficient
correlation_coefficient = Travel['Lead time'].corr(Travel['Accommodation cost'])
print(f"Correlation Coefficient: {correlation_coefficient}")
# Out:
# Correlation Coefficient: 0.09088176832632416

# %% [markdown]
# <span style="font-family:Calibri"><span style="color:pink">
# >Is there a relationship between the type of accommodation and the mode of transportation chosen ?</span>

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Create a cross-tabulation
cross_tab = pd.crosstab(Travel['Accommodation type'], Travel['Transportation type'])

# Plot a heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(cross_tab, annot=True, cmap="YlGnBu", fmt='d', cbar_kws={'label': 'Count'})
plt.title('Relationship Between Accommodation and Transportation')
plt.xlabel('Transportation Type')
plt.ylabel('Accommodation Type')
plt.show()

# %% [markdown]
# <span style="color:Orange">
#
# ***Data Visualization / Plotting :***
#
# </span>
#
# <span style="font-family:Calibri"><span style="color:pink">
# >Create a timeline or trend chart showing the distribution of trip durations.</span>

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Convert 'Start date' and 'End date' to datetime format
Travel['Start date'] = pd.to_datetime(Travel['Start date'])
Travel['End date'] = pd.to_datetime(Travel['End date'])

# Calculate trip durations
Travel['Trip duration'] = (Travel['End date'] - Travel['Start date']).dt.days

# Create a histogram to show the distribution of trip durations
plt.figure(figsize=(10, 6))
plt.hist(Travel['Trip duration'], bins=20, color='skyblue', edgecolor='black')
plt.title('Distribution of Trip Durations')
plt.xlabel('Trip Duration (days)')
plt.ylabel('Number of Trips')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %% [markdown]
# <span style="font-family:Calibri"><span style="color:pink">
# >Create a heatmap to show the busiest months for travel across all destinations.<span>

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# Assuming your travel data is stored in a DataFrame named 'travel_data'
# Make sure your 'Start date' column is in datetime format

# Convert 'Start date' to datetime if it's not already
Travel['Start date'] = pd.to_datetime(Travel['Start date'])

# Extract month and year from the 'Start date'
Travel['Month'] = Travel['Start date'].dt.month

# Create a pivot table with destination as index, month as columns, and count of trips as values
heatmap_data = pd.pivot_table(Travel, values='Trip ID', index='Destination', columns='Month', aggfunc='count', fill_value=0)

# Set up the heatmap using seaborn
plt.figure(figsize=(14, 14))
sns.heatmap(heatmap_data, cmap='YlGnBu', annot=True, fmt='g', cbar_kws={'label': 'Number of Trips'})
plt.title('Busiest Months for Travel Across Destinations')
plt.xlabel('Month')
plt.ylabel('Destination')

plt.show()

# %% [markdown]
# <span style="font-family:Calibri"><span style="color:pink">
# >Use a grouped bar chart to compare the distribution of nationalities across destinations.</span>

# %%
import matplotlib.pyplot as plt
import pandas as pd

Travel_grpbarchart = pd.read_excel(file1, sheet_name='Travel details dataset', header=0)

# Extract relevant columns
nationality_data = Travel_grpbarchart[['Destination', 'Traveler nationality']]

# Group by Destination and Traveler nationality, count occurrences
grouped_data = nationality_data.groupby(['Destination', 'Traveler nationality']).size().unstack()

# Plotting the grouped bar chart
grouped_data.plot(kind='bar', stacked=True, figsize=(12, 8))
plt.title('Distribution of Nationalities Across Destinations')
plt.xlabel('Destination')
plt.ylabel('Number of Travelers')
plt.legend(title='Nationality', bbox_to_anchor=(1, 1), loc='upper left')

plt.show()

# %% [markdown]
# <span style="font-family:Calibri"><span style="color:orange">Conclusion</span>
#
# <span style="font-family:Calibri">The exploratory data analysis project on the Travel Insights dataset has unveiled a trove of valuable insights into travel behavior, demographics, and operational patterns. These findings are poised to revolutionize decision-making processes for travel agencies, tourism boards, and related businesses, empowering them to tailor their services with precision to meet the diverse preferences and needs of travelers. Leveraging visualization techniques throughout the analysis has not only enhanced the interpretability of the insights but also enriched their communicability, ensuring stakeholders can grasp the nuances of the data effortlessly.</span>
#
# <span style="font-family:Calibri">Moreover, the additional findings presented further deepen our understanding of the multifaceted dynamics shaping travel trends. This expanded comprehension encompasses various factors influencing traveler behavior, preferences, and operational intricacies. By harnessing these insights, businesses and stakeholders within the travel industry can make strategic decisions rooted in data-driven intelligence. This includes enhancing customer experiences, optimizing resource allocation, and driving sustainable business growth. The rigorous application of data analysis techniques and visualization methods underscores the robustness and reliability of these findings, paving the way for actionable outcomes and informed strategic planning initiatives that propel the industry forward.</span>
